# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv('/Users/remy.d.w/PycharmProjects/nlp/text-extraction/TextFiles/smsspamcollection.tsv', sep='\t')
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
# access to element like a numpy array 
df.describe()
# Out:
#             length        punct
# count  5572.000000  5572.000000
# mean     80.489950     4.177495
# std      59.942907     4.623919
# min       2.000000     0.000000
# 25%      36.000000     2.000000
# 50%      62.000000     3.000000
# 75%     122.000000     6.000000
# max     910.000000   133.000000

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
# values return a numpy array 
test_df = pd.DataFrame()
test_df['easy'] = df['label'].values
df['label'].values
# Out:
# array(['ham', 'ham', 'spam', ..., 'ham', 'ham', 'ham'], dtype=object)

# %%
test_df.head()
# Out:
#    easy
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham

# %%
rename = test_df.rename(columns={'easy':'hello'})

# %%
rename.head()
# Out:
#   hello
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham

# %%
sns.catplot(x='label', y='length',data=df, hue='punct')

# %%
sns.pairplot(data=df)
